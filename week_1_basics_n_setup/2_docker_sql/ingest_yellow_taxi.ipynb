# %%
from sqlalchemy import create_engine
import pandas as pd
from time import time

# %%
user = "root"
password = "root"
host = "localhost"
port = 5432
db = "ny_taxi"
url = f"postgresql://{user}:{password}@{host}:{port}/{db}"
engine = create_engine(url)

# %%
df_iter = pd.read_csv('yellow_tripdata_2021-01.csv', iterator=True, chunksize=100000)

# %%
df = next(df_iter)
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1             1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2             1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3             1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4             2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ...         ...                  ...                   ...              ...
# 99995         1  2021-01-04 14:04:31   2021-01-04 14:08:52                3
# 99996         1  2021-01-04 14:18:46   2021-01-04 14:35:45                2
# 99997         1  2021-01-04 14:42:41   2021-01-04 14:59:22                2
# 99998         2  2021-01-04 14:39:02   2021-01-04 15:09:37                2
# 99999         2  2021-01-04 14:49:36   2021-01-04 14:54:44                5
#
#        trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0               2.10           1                  N           142
# 1               0.20           1                  N           238
# 2              14.70           1                  N           132
# 3              10.60           1                  N           138
# 4               4.94           1                  N            68
# ...              ...         ...                ...           ...
# 99995           0.70           1                  N           234
# 99996           3.30           1                  N           234
# 99997           4.70           1                  N           236
# 99998          17.95           2                  N           132
# 99999           0.37           1                  N           236
#
#        DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                43             2          8.0    3.0      0.5        0.00
# 1               151             2          3.0    0.5      0.5        0.00
# 2               165             1         42.0    0.5      0.5        8.65
# 3               132             1         29.0    0.5      0.5        6.05
# 4                33             1         16.5    0.5      0.5        4.06
# ...             ...           ...          ...    ...      ...         ...
# 99995           224             2          5.0    2.5      0.5        0.00
# 99996           236             1         14.5    2.5      0.5        3.55
# 99997            79             1         17.0    2.5      0.5        4.05
# 99998           148             1         52.0    0.0      0.5        5.00
# 99999           236             2          5.0    0.0      0.5        0.00
#
#        tolls_amount  improvement_surcharge  total_amount  congestion_surcharge
# 0               0.0                    0.3         11.80                   2.5
# 1               0.0                    0.3          4.30                   0.0
# 2               0.0                    0.3         51.95                   0.0
# 3               0.0                    0.3         36.35                   0.0
# 4               0.0                    0.3         24.36                   2.5
# ...             ...                    ...           ...                   ...
# 99995           0.0                    0.3          8.30                   2.5
# 99996           0.0                    0.3         21.35                   2.5
# 99997           0.0                    0.3         24.35                   2.5
# 99998           0.0                    0.3         60.30                   2.5
# 99999           0.0                    0.3          8.30                   2.5
#
# [100000 rows x 18 columns]

# %%
print(pd.io.sql.get_schema(df, 'yellow_taxi'))
# Out:
# CREATE TABLE "yellow_taxi" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "RatecodeID" INTEGER,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

# %%
print(pd.io.sql.get_schema(df, 'yellow_taxi'))
# Out:
# CREATE TABLE "yellow_taxi" (
# "VendorID" INTEGER,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "RatecodeID" INTEGER,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" INTEGER,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
df.head(n=0).to_sql(name='yellow_taxi', con=engine, if_exists='replace')

# %%
# %time df.to_sql(name='yellow_taxi', con=engine, if_exists='append')
# Out:
# CPU times: user 11.6 s, sys: 4.63 s, total: 16.2 s
# Wall time: 1min 23s

# %%
while True:
    t_start = time()
    df = next(df_iter)

    df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
    df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)

    df.to_sql(name='yellow_taxi', con=engine, if_exists='append')

    t_end = time()
    print("inserted chunk... took %.3f second" % (t_end-t_start))
# Out:
# inserted chunk... took 75.131 second
# inserted chunk... took 76.554 second
# inserted chunk... took 76.181 second
# inserted chunk... took 77.019 second
# inserted chunk... took 75.795 second
# inserted chunk... took 78.697 second
# inserted chunk... took 79.127 second
# inserted chunk... took 79.484 second
# inserted chunk... took 82.837 second
# inserted chunk... took 81.168 second
# inserted chunk... took 82.800 second
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3191: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   if await self.run_code(code, result, async_=asy):
# inserted chunk... took 84.852 second
# inserted chunk... took 59.100 second
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /Users/mufidnuha/Desktop/data-engineering-zoomcamp/2_docker_sql/ingest_yellow_taxi.ipynb Cell 10' in <module>
#       <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/data-engineering-zoomcamp/2_docker_sql/ingest_yellow_taxi.ipynb#ch0000009?line=0'>1</a> while True:
#       <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/data-engineering-zoomcamp/2_docker_sql/ingest_yellow_taxi.ipynb#ch0000009?line=1'>2</a>     t_start = time()
# ----> <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/data-engineering-zoomcamp/2_docker_sql/ingest_yellow_taxi.ipynb#ch0000009?line=2'>3</a>     df = next(df_iter)
#       <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/data-engineering-zoomcamp/2_docker_sql/ingest_yellow_taxi.ipynb#ch0000009?line=4'>5</a>     df.tpep_pickup_datetime = pd.to_datetime(df.tpep_pickup_datetime)
#       <a href='vscode-notebook-cell:/Users/mufidnuha/Desktop/data-engineering-zoomcamp/2_docker_sql/ingest_yellow_taxi.ipynb#ch0000009?line=5'>6</a>     df.tpep_dropoff_datetime = pd.to_datetime(df.tpep_dropoff_datetime)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1024, in TextFileReader.__next__(self)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py?line=1021'>1022</a> def __next__(self):
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py?line=1022'>1023</a>     try:
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py?line=1023'>1024</a>         return self.get_chunk()
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py?line=1024'>1025</a>     except StopIteration:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py?line=1025'>1026</a>         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1074, in TextFileReader.get_chunk(self, size)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py?line=1071'>1072</a>         raise StopIteration
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py?line=1072'>1073</a>     size = min(size, self.nrows - self._currow)
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py?line=1073'>1074</a> return self.read(nrows=size)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1047, in TextFileReader.read(self, nrows)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py?line=1044'>1045</a> def read(self, nrows=None):
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py?line=1045'>1046</a>     nrows = validate_integer("nrows", nrows)
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py?line=1046'>1047</a>     index, columns, col_dict = self._engine.read(nrows)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py?line=1048'>1049</a>     if index is None:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py?line=1049'>1050</a>         if col_dict:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/readers.py?line=1050'>1051</a>             # Any column is actually fine:
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py:224, in CParserWrapper.read(self, nrows)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=221'>222</a> try:
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=222'>223</a>     if self.low_memory:
# --> <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=223'>224</a>         chunks = self._reader.read_low_memory(nrows)
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=224'>225</a>         # destructive to chunks
#     <a href='file:///Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=225'>226</a>         data = _concatenate_chunks(chunks)
#
# File /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/_libs/parsers.pyx:826, in pandas._libs.parsers.TextReader.read_low_memory()
#
# StopIteration:
